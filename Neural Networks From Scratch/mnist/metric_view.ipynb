# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
metrics = pd.read_csv("Models/test_metrics.csv", index_col=0)
metrics
# Out:
#           loss  ema_loss  accuracy
# 0     2.415158  2.415158  0.109375
# 1     2.127639  2.412283  0.316406
# 2     1.897945  2.407139  0.488281
# 3     1.648934  2.399557  0.597656
# 4     1.511566  2.390677  0.648438
# ...        ...       ...       ...
# 7045  0.001655  0.006723  1.000000
# 7046  0.027174  0.006927  0.996094
# 7047  0.002960  0.006888  1.000000
# 7048  0.045277  0.007272  0.984375
# 7049  0.006001  0.007259  1.000000
#
# [7050 rows x 3 columns]

# %%
loss_fig, loss_ax = plt.subplots()
loss_ax.plot(metrics["loss"])
loss_ax.set_xlabel("Step")
loss_ax.set_ylabel("Loss")
loss_ax.set_title("Loss Over Time")

ema_fig, ema_ax = plt.subplots()
ema_ax.plot(metrics["ema_loss"])
ema_ax.set_xlabel("Step")
ema_ax.set_ylabel("EMA Loss")
ema_ax.set_title("EMA Loss Over Time")

acc_fig, acc_ax = plt.subplots()
acc_ax.plot(metrics["accuracy"])
acc_ax.set_xlabel("Step")
acc_ax.set_ylabel("Accuracy")
acc_ax.set_title("Accuracy Over Time")
plt.show()
