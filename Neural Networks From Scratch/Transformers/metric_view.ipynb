# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
metrics = pd.read_csv("TinychatModels/better_tinychat_metrics.csv", index_col=0)
metrics
# Out:
#           loss  ema_loss  accuracy
# 1     9.870449  9.870449  0.000000
# 2    10.153684  9.873281  0.000000
# 3     9.928358  9.873832  0.000000
# 4     9.912358  9.874217  0.000000
# 5     9.622412  9.871699  0.000000
# ..         ...       ...       ...
# 496   6.720501  6.197937  0.042969
# 497   6.294254  6.198900  0.023438
# 498   6.445366  6.201365  0.039062
# 499   6.395569  6.203307  0.035156
# 500   5.968375  6.200958  0.039062
#
# [500 rows x 3 columns]

# %%
loss_fig, loss_ax = plt.subplots()
loss_ax.plot(metrics["loss"])
loss_ax.set_xlabel("Step")
loss_ax.set_ylabel("Loss")
loss_ax.set_title("Loss Over Time")

ema_fig, ema_ax = plt.subplots()
ema_ax.plot(metrics["ema_loss"])
ema_ax.set_xlabel("Step")
ema_ax.set_ylabel("EMA Loss")
ema_ax.set_title("EMA Loss Over Time")

acc_fig, acc_ax = plt.subplots()
acc_ax.plot(metrics["accuracy"])
acc_ax.set_xlabel("Step")
acc_ax.set_ylabel("Accuracy")
acc_ax.set_title("Accuracy Over Time")
plt.show()
