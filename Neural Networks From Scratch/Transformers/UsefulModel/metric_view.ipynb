# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
metrics = pd.read_csv("Models/useful_model_metrics.csv", index_col=0)
metrics
# Out:
#            loss  ema_loss  accuracy  learning_rate
# 1      9.874784  9.874784  0.000000   2.500000e-07
# 2      9.827170  9.874308  0.000000   5.000000e-07
# 3      9.864826  9.874214  0.000000   7.500000e-07
# 4      9.930785  9.874779  0.000000   1.000000e-06
# 5      9.893859  9.874970  0.000244   1.250000e-06
# ...         ...       ...       ...            ...
# 13996  4.153772  4.238250  0.301514   1.906664e-04
# 13997  4.355354  4.239421  0.281250   1.906581e-04
# 13998  4.079415  4.237821  0.302490   1.906499e-04
# 13999  4.293149  4.238374  0.284180   1.906416e-04
# 14000  4.204359  4.238034  0.305176   1.906333e-04
#
# [14000 rows x 4 columns]

# %%
loss_fig, loss_ax = plt.subplots()
loss_ax.plot(metrics["loss"])
loss_ax.set_xlabel("Step")
loss_ax.set_ylabel("Loss")
loss_ax.set_title("Loss Over Time")

ema_fig, ema_ax = plt.subplots()
ema_ax.plot(metrics["ema_loss"])
ema_ax.set_xlabel("Step")
ema_ax.set_ylabel("EMA Loss")
ema_ax.set_title("EMA Loss Over Time")

acc_fig, acc_ax = plt.subplots()
acc_ax.plot(metrics["accuracy"])
acc_ax.set_xlabel("Step")
acc_ax.set_ylabel("Accuracy")
acc_ax.set_title("Accuracy Over Time")
plt.show()

# %%
logged_ema_loss = pd.DataFrame(np.log(metrics["ema_loss"]))
ema_fig, ema_ax = plt.subplots()
ema_ax.plot(logged_ema_loss)
ema_ax.set_xlabel("Step")
ema_ax.set_ylabel("EMA Loss")
ema_ax.set_title("EMA Loss Over Time")
# Out:
# Text(0.5, 1.0, 'EMA Loss Over Time')
