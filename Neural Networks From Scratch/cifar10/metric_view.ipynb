# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
metrics = pd.read_csv("Models/cifar_conv_metrics.csv", index_col=0)
metrics
# Out:
#            loss  ema_loss  accuracy
# 0      4.396410  4.396410  0.046875
# 1      4.222355  4.394669  0.046875
# 2      4.437560  4.395098  0.109375
# 3      4.380543  4.394953  0.078125
# 4      4.539988  4.396403  0.078125
# ...         ...       ...       ...
# 31275  0.706123  0.611731  0.718750
# 31276  0.805004  0.613664  0.718750
# 31277  0.691696  0.614444  0.765625
# 31278  0.459635  0.612896  0.843750
# 31279  0.575009  0.612517  0.750000
#
# [31280 rows x 3 columns]

# %%
loss_fig, loss_ax = plt.subplots()
loss_ax.plot(metrics["loss"])
loss_ax.set_xlabel("Step")
loss_ax.set_ylabel("Loss")
loss_ax.set_title("Loss Over Time")

ema_fig, ema_ax = plt.subplots()
ema_ax.plot(metrics["ema_loss"])
ema_ax.set_xlabel("Step")
ema_ax.set_ylabel("EMA Loss")
ema_ax.set_title("EMA Loss Over Time")

acc_fig, acc_ax = plt.subplots()
acc_ax.plot(metrics["accuracy"])
acc_ax.set_xlabel("Step")
acc_ax.set_ylabel("Accuracy")
acc_ax.set_title("Accuracy Over Time")
plt.show()
