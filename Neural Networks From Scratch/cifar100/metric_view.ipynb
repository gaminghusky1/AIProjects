# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
metrics = pd.read_csv("Models/cifar100_conv_metrics.csv", index_col=0)
metrics
# Out:
#            loss  ema_loss  accuracy
# 0      4.705560  4.705560   0.00000
# 1      4.653336  4.705038   0.00000
# 2      4.759306  4.705581   0.03125
# 3      4.660379  4.705129   0.03125
# 4      4.712412  4.705201   0.03125
# ...         ...       ...       ...
# 78145  1.483161  1.396319   0.56250
# 78146  0.843313  1.390789   0.65625
# 78147  1.694932  1.393830   0.56250
# 78148  1.290481  1.392796   0.56250
# 78149  2.158276  1.400451   0.25000
#
# [78150 rows x 3 columns]

# %%
loss_fig, loss_ax = plt.subplots()
loss_ax.plot(metrics["loss"])
loss_ax.set_xlabel("Step")
loss_ax.set_ylabel("Loss")
loss_ax.set_title("Loss Over Time")

ema_fig, ema_ax = plt.subplots()
ema_ax.plot(metrics["ema_loss"])
ema_ax.set_xlabel("Step")
ema_ax.set_ylabel("EMA Loss")
ema_ax.set_title("EMA Loss Over Time")

acc_fig, acc_ax = plt.subplots()
acc_ax.plot(metrics["accuracy"])
acc_ax.set_xlabel("Step")
acc_ax.set_ylabel("Accuracy")
acc_ax.set_title("Accuracy Over Time")
plt.show()
